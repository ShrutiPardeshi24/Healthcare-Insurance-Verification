# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrutiPardeshi24/Healthcare-Insurance-Verification/blob/main/Healthcare_insurance_eligibility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
import streamlit as st
import pandas as pd
import requests
import json
from datetime import datetime, timedelta
from io import StringIO
import plotly.express as px
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
@st.cache_data
def load_test_dataset():
    try:
        url = "https://raw.githubusercontent.com/prasad22/healthcare-dataset/main/healthcare_dataset.csv"
        df = pd.read_csv(url)
        return df[['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition', 'Insurance Sector']].head(10)
    except:
        return pd.DataFrame({
            'Name': ['John Doe', 'Jane Smith', 'Bob Johnson'],
            'Age': [45, 32, 67],
            'Insurance Sector': ['AETNA', 'CIGNA', 'UNITED']
        })

df = load_test_dataset()
df
# Out:
# 2026-03-28 03:07:05.192 No runtime found, using MemoryCacheStorageManager
#           Name  Age Insurance Sector
# 0     John Doe   45            AETNA
# 1   Jane Smith   32            CIGNA
# 2  Bob Johnson   67           UNITED

# %%
@st.cache_data
def mock_eligibility_check(patient_data, payer="AETNA"):
    """HIPAA 270/271 Stedi-style response"""
    payers = {
        "AETNA": {"active": True, "copay": "$20", "deductible": "Met"},
        "CIGNA": {"active": True, "copay": "$30", "deductible": "Remaining $500"},
        "UNITED": {"active": False, "reason": "Expired"}
    }
    return payers.get(payer.upper(), {"active": False, "reason": "Unknown"})

def mock_healthie_booking(patient_data):
    """Healthie GraphQL createAppointment simulation"""
    return {
        "appointment_id": f"appt_{int(datetime.now().timestamp())}",
        "status": "confirmed",
        "start_time": (datetime.now() + timedelta(days=3)).isoformat()
    }

# Test APIs
test_patient = {"first_name": "John", "last_name": "Doe", "member_id": "MB123"}
print("AETNA:", mock_eligibility_check(test_patient, "AETNA"))
print("UNITED:", mock_eligibility_check(test_patient, "UNITED"))
# Out:
# 2026-03-28 03:07:05.215 No runtime found, using MemoryCacheStorageManager
# AETNA: {'active': True, 'copay': '$20', 'deductible': 'Met'}
# UNITED: {'active': False, 'reason': 'Expired'}

# %%
import os

# COMPLETE PRODUCTION APP - Copy this entire cell to app.py
streamlit_app_code = '''
import streamlit as st
import pandas as pd
from datetime import datetime, timedelta

st.set_page_config(page_title="Healthcare System", layout="wide")

@st.cache_data
def load_test_dataset():
    # Kaggle dataset
    return pd.DataFrame({
        'Name': ['John Doe', 'Jane Smith'],
        'Insurance': ['AETNA', 'UNITED']
    })

@st.cache_data
def mock_eligibility(patient_data, payer):
    if payer == 'AETNA':
        return {'active': True, 'copay': '$20'}
    return {'active': False}

def main():
    st.title('🩺 Insurance + Appointment System')

    with st.form('patient'):
        name = st.text_input('Name')
        payer = st.selectbox('Payer', ['AETNA', 'UNITED'])
        submit = st.form_submit_button('Verify & Book')

    if submit:
        eligibility = mock_eligibility({'name': name}, payer)
        if eligibility['active']:
            st.success('✅ Booked!')
        else:
            st.error('❌ Ineligible')

if __name__ == '__main__':
    main()
'''

# Ensure the output directory exists
os.makedirs('output', exist_ok=True)

# Save app file
with open('output/healthcare_app.py', 'w') as f:
    f.write(streamlit_app_code)
print('✅ App saved: healthcare_app.py')
print('📱 Deploy: https://share.streamlit.io')

# Show code
print('\n' + '='*50)
print('COPY THIS TO app.py:')
print(streamlit_app_code)
# Out:
# ✅ App saved: healthcare_app.py
# 📱 Deploy: https://share.streamlit.io
#
# ==================================================
# COPY THIS TO app.py:
#
# import streamlit as st
# import pandas as pd
# from datetime import datetime, timedelta
#
# st.set_page_config(page_title="Healthcare System", layout="wide")
#
# @st.cache_data
# def load_test_dataset():
#     # Kaggle dataset
#     return pd.DataFrame({
#         'Name': ['John Doe', 'Jane Smith'],
#         'Insurance': ['AETNA', 'UNITED']
#     })
#
# @st.cache_data
# def mock_eligibility(patient_data, payer):
#     if payer == 'AETNA':
#         return {'active': True, 'copay': '$20'}
#     return {'active': False}
#
# def main():
#     st.title('🩺 Insurance + Appointment System')
#
#     with st.form('patient'):
#         name = st.text_input('Name')
#         payer = st.selectbox('Payer', ['AETNA', 'UNITED'])
#         submit = st.form_submit_button('Verify & Book')
#
#     if submit:
#         eligibility = mock_eligibility({'name': name}, payer)
#         if eligibility['active']:
#             st.success('✅ Booked!')
#         else:
#             st.error('❌ Ineligible')
#
# if __name__ == '__main__':
#     main()

# %%
import streamlit as st
import pandas as pd
from datetime import datetime, timedelta

st.set_page_config(page_title="Healthcare System", layout="wide")

@st.cache_data
def load_test_dataset():
    # Kaggle dataset
    return pd.DataFrame({
        'Name': ['John Doe', 'Jane Smith'],
        'Insurance': ['AETNA', 'UNITED']
    })

@st.cache_data
def mock_eligibility(patient_data, payer):
    if payer == 'AETNA':
        return {'active': True, 'copay': '$20'}
    return {'active': False}

def main():
    st.title('🩺 Insurance + Appointment System')

    with st.form('patient'):
        name = st.text_input('Name')
        payer = st.selectbox('Payer', ['AETNA', 'UNITED'])
        submit = st.form_submit_button('Verify & Book')

    if submit:
        eligibility = mock_eligibility({'name': name}, payer)
        if eligibility['active']:
            st.success('✅ Booked!')
        else:
            st.error('❌ Ineligible')

if __name__ == '__main__':
    main()
# Out:
# 2026-03-28 03:07:05.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.248 No runtime found, using MemoryCacheStorageManager
# 2026-03-28 03:07:05.250 No runtime found, using MemoryCacheStorageManager
# 2026-03-28 03:07:05.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-28 03:07:05.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import subprocess

# Streamlit might not run interactively in Colab output, but this will generate a link
# to access the app in a new tab.
print('Running Streamlit app. Look for a public URL in the output.')

# Use subprocess to run streamlit command to avoid blocking the notebook if it fails
# and to capture its output.
# You might need to adjust the port if 8501 is already in use.
process = subprocess.Popen(['streamlit', 'run', 'output/healthcare_app.py', '--server.port', '8501', '--server.enableCORS', 'false', '--server.enableXsrfProtection', 'false'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# For simplicity, we just print a message. In a real scenario, you'd want to parse
# the output to find the URL or use a dedicated Colab-Streamlit integration library.
print("Streamlit app is starting... check the new tab or the output for the URL.")

# This won't show the interactive app directly in Colab's output, but it should print
# the URL to access it.
# Out:
# Running Streamlit app. Look for a public URL in the output.
# Streamlit app is starting... check the new tab or the output for the URL.

# %% [markdown]
# Alternatively, you can run the app directly from your terminal using `streamlit run output/healthcare_app.py` if you have Streamlit installed locally, or deploy it to Streamlit Sharing as suggested in the previous output.
